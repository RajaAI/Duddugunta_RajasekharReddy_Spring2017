# %%
import nltk

# %%
from nltk.corpus import gutenberg

# %%
from nltk.corpus import web_text
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-518bfea3d9d5> in <module>()
# ----> 1 from nltk.corpus import web_text
#
# ImportError: cannot import name 'web_text'

# %%
from nltk.corpus import webtext

# %%
firstfiles=gutenberg.fileids()

# %%
secondfiles=webtext.fileids()

# %%
firstfiles
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
secondfiles
# Out:
# ['firefox.txt',
#  'grail.txt',
#  'overheard.txt',
#  'pirates.txt',
#  'singles.txt',
#  'wine.txt']

# %%
nltk.corpus.words('gutenberg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-5f9857a947b0> in <module>()
# ----> 1 nltk.corpus.words('gutenberg')
#
# TypeError: 'LazyCorpusLoader' object is not callable

# %%
nltk.corpus.words(gutenberg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-22942b08f158> in <module>()
# ----> 1 nltk.corpus.words(gutenberg)
#
# TypeError: 'LazyCorpusLoader' object is not callable

# %%
file1=nltk.corpus.gutenberg.words('austen-emma.txt')

# %%
file2=nltk.corpus.gutenberg.words('austen-persuasion.txt','austen-sense.txt')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-acc61de155ca> in <module>()
# ----> 1 file2=nltk.corpus.gutenberg.words('austen-persuasion.txt','austen-sense.txt')
#
# TypeError: words() takes from 1 to 2 positional arguments but 3 were given

# %%
file2=nltk.corpus.gutenberg.words('austen-persuasion.txt'+'austen-sense.txt')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-44b254c80fbe> in <module>()
# ----> 1 file2=nltk.corpus.gutenberg.words('austen-persuasion.txt'+'austen-sense.txt')
#
# C:\Users\rajas\Anaconda3\lib\site-packages\nltk\corpus\reader\plaintext.py in words(self, fileids)
#      87         return concat([self.CorpusView(path, self._read_word_block, encoding=enc)
#      88                        for (path, enc, fileid)
# ---> 89                        in self.abspaths(fileids, True, True)])
#      90
#      91     def sents(self, fileids=None):
#
# C:\Users\rajas\Anaconda3\lib\site-packages\nltk\corpus\reader\api.py in abspaths(self, fileids, include_encoding, include_fileid)
#     188             fileids = [fileids]
#     189
# --> 190         paths = [self._root.join(f) for f in fileids]
#     191
#     192         if include_encoding and include_fileid:
#
# ...

# %%
file2=nltk.corpus.gutenberg.words('austen-persuasion.txt')

# %%
file20=file1+file2

# %%
file20
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', ...]

# %%
file1
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', ...]

# %%
len(file20)
# Out:
# 290598

# %%
len(file1)
# Out:
# 192427

# %%
len(file2)
# Out:
# 98171

# %%
file3=nltk.corpus.gutenberg.words('austen-sense.txt')

# %%
file4=nltk.corpus.gutenberg.words('bible-kjv.txt')
file5=nltk.corpus.gutenberg.words('blake-poems.txt')
file6=nltk.corpus.gutenberg.words('bryant-stories.txt')
file7=nltk.corpus.gutenberg.words('burgess-busterbrown.txt')
file8=nltk.corpus.gutenberg.words('carroll-alice.txt')
file9=nltk.corpus.gutenberg.words('chesterton-ball.txt')
file10=nltk.corpus.gutenberg.words('chesterton-thursday.txt')
file11=nltk.corpus.gutenberg.words('edgeworth-parents.txt')
file12=nltk.corpus.gutenberg.words('melville-moby_dick.txt')
file13=nltk.corpus.gutenberg.words('milton-paradise.txt')
file14=nltk.corpus.gutenberg.words('shakespeare-caesar.txt')
file15=nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')
file16=nltk.corpus.gutenberg.words('shakespeare-macbeth.txt')
file17=nltk.corpus.gutenberg.words('whitman-leaves.txt')
file18=nltk.corpus.gutenberg.words('firefox.txt')
file19=nltk.corpus.gutenberg.words('grail.txt')
file20=nltk.corpus.gutenberg.words('overheard.txt')
file21=nltk.corpus.gutenberg.words('pirates.txt')
file22=nltk.corpus.gutenberg.words('singles.txt')
file23=nltk.corpus.gutenberg.words('wine.txt')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-8165e7a9d68d> in <module>()
#      13 file16=nltk.corpus.gutenberg.words('shakespeare-macbeth.txt')
#      14 file17=nltk.corpus.gutenberg.words('whitman-leaves.txt')
# ---> 15 file18=nltk.corpus.gutenberg.words('firefox.txt')
#      16 file19=nltk.corpus.gutenberg.words('grail.txt')
#      17 file20=nltk.corpus.gutenberg.words('overheard.txt')
#
# C:\Users\rajas\Anaconda3\lib\site-packages\nltk\corpus\reader\plaintext.py in words(self, fileids)
#      87         return concat([self.CorpusView(path, self._read_word_block, encoding=enc)
#      88                        for (path, enc, fileid)
# ---> 89                        in self.abspaths(fileids, True, True)])
#      90
#      91     def sents(self, fileids=None):
#
# ...

# %%
file4=nltk.corpus.gutenberg.words('bible-kjv.txt')
file5=nltk.corpus.gutenberg.words('blake-poems.txt')
file6=nltk.corpus.gutenberg.words('bryant-stories.txt')
file7=nltk.corpus.gutenberg.words('burgess-busterbrown.txt')
file8=nltk.corpus.gutenberg.words('carroll-alice.txt')
file9=nltk.corpus.gutenberg.words('chesterton-ball.txt')
file10=nltk.corpus.gutenberg.words('chesterton-thursday.txt')
file11=nltk.corpus.gutenberg.words('edgeworth-parents.txt')
file12=nltk.corpus.gutenberg.words('melville-moby_dick.txt')
file13=nltk.corpus.gutenberg.words('milton-paradise.txt')
file14=nltk.corpus.gutenberg.words('shakespeare-caesar.txt')
file15=nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')
file16=nltk.corpus.gutenberg.words('shakespeare-macbeth.txt')
file17=nltk.corpus.gutenberg.words('whitman-leaves.txt')
file18=nltk.corpus.webtext.words('firefox.txt')
file19=nltk.corpus.webtext.words('grail.txt')
file20=nltk.corpus.webtext.words('overheard.txt')
file21=nltk.corpus.webtext.words('pirates.txt')
file22=nltk.corpus.webtext.words('singles.txt')
file23=nltk.corpus.webtext.words('wine.txt')

# %%
finalfile=file1+file2+file3+file4+file5+file6+file7+file8+file9+file10+file11+file12+file13+file14+file15+file16+file17+file18+file19+file20+file21+file22+file23

# %%
finalfile
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', ...]

# %%
len(finalfile)
# Out:
# 2932283

# %%
shakesperewords=file14+file15+file16
webwords=file18+file19+file20+file21+file22+file23

# %%
finalwords=shakesperewords+webwords

# %%
order=FreqDist(finalwords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-949d6d9154f0> in <module>()
# ----> 1 order=FreqDist(finalwords)
#
# NameError: name 'FreqDist' is not defined

# %%
words(finalwords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-610a2beb3a88> in <module>()
# ----> 1 words(finalwords)
#
# NameError: name 'words' is not defined

# %%
words('finalwords')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-776950c6b9d5> in <module>()
# ----> 1 words('finalwords')
#
# NameError: name 'words' is not defined

# %%
nltk.corpus.gutenberg.words('shakesperewords')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-32-ad916d01b5a7> in <module>()
# ----> 1 nltk.corpus.gutenberg.words('shakesperewords')
#
# C:\Users\rajas\Anaconda3\lib\site-packages\nltk\corpus\reader\plaintext.py in words(self, fileids)
#      87         return concat([self.CorpusView(path, self._read_word_block, encoding=enc)
#      88                        for (path, enc, fileid)
# ---> 89                        in self.abspaths(fileids, True, True)])
#      90
#      91     def sents(self, fileids=None):
#
# C:\Users\rajas\Anaconda3\lib\site-packages\nltk\corpus\reader\api.py in abspaths(self, fileids, include_encoding, include_fileid)
#     188             fileids = [fileids]
#     189
# --> 190         paths = [self._root.join(f) for f in fileids]
#     191
#     192         if include_encoding and include_fileid:
#
# ...

# %%
finalwords.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-192946b3a550> in <module>()
# ----> 1 finalwords.split()
#
# AttributeError: 'LazyConcatenation' object has no attribute 'split'

# %%
for word in finalwords:
    if word not in wordcount:
        wordcount[word] = 1
    else:
        wordcount[word] += 1

for k,v in wordcount.items():
    print (k, v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-6d5ed5a75165> in <module>()
#       1 for word in finalwords:
# ----> 2     if word not in wordcount:
#       3         wordcount[word] = 1
#       4     else:
#       5         wordcount[word] += 1
#
# NameError: name 'wordcount' is not defined

# %%
wordcount={}

for word in finalwords:
    if word not in wordcount:
        wordcount[word] = 1
    else:
        wordcount[word] += 1

for k,v in wordcount.items():
    print (k, v)
# Out:
# sunshine 1
# clothes 27
# crap 9
# methods 3
# Lafayette 1
# pages 143
# noticeable 1
# Applets 4
# mpg 2
# del 1
# Hostesse 5
# xremote 5
# unarmed 1
# modified 7
# deseru 4
# children 46
# covering 2
# Copied 1
# Folded 1
# Beard 4
# Savvy 3
# ANTIOXIDANTS 1
# Counsellor 1
# Slavery 1
# Recover 1
# thunder 3
# Full 25
# napkins 1
# Doth 5
# Amongst 1
# threats 3
# vache 2
# shittiest 1
# persecuted 3
# explain 12
# Leaner 1
# brownstone 2
# Slideshow 1
# muddied 1
# Chorus 1
# schooled 1
# contributor 5
# Trainer 1
# Puzels 1
# remain 8
# Windes 1
# Unpleasant 1
# Pomerol 1
# fearefulnesse 1
# Heart 18
# How 266
# mouthes 2
# roundhouse 1
# parameter 10
# newes 10
# whereon 3
# reside 1
# harshness 1
# DAD 2
# Parkinson 1
# systematic 1
# Simpsons 2
# Pieman 1
# speeches 1
# Huy 1
# Arabic 2
# javaEnabled 1
# martial 2
# instead 139
# ASK 1
# Will 221
# 0x00568bbd 1
# promise 15
# Continues 1
# def 2
# UX 1
# ball 14
# cook 8
# comlexity 1
# LOVER 2
# wormes 2
# Maisters 1
# ...

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
order=FreqDist(finalwords)

# %%
top=order.most_common(50)

# %%
top
# Out:
# [('.', 22106),
#  (',', 19378),
#  (':', 15655),
#  ("'", 12487),
#  ('I', 9245),
#  ('the', 9211),
#  ('to', 7522),
#  ('a', 6647),
#  ('you', 5509),
#  ('and', 5473),
#  ('?', 5339),
#  ('in', 4931),
#  ('of', 4365),
#  ('!', 4102),
#  ('#', 3710),
#  ('t', 3664),
#  ('-', 3581),
#  ('is', 3579),
#  ('s', 3551),
#  ('on', 3488),
#  ('it', 3263),
#  ('not', 3128),
#  ('that', 2894),
#  ('"', 2601),
#  ('with', 2387),
#  ('1', 2320),
#  ('for', 2223),
#  ('my', 2140),
#  ('me', 1830),
#  ('Girl', 1755),
#  ('2', 1750),
#  ('be', 1735),
#  ('like', 1722),
#  ('when', 1709),
#  ('this', 1671),
#  ('Guy', 1659),
#  ('...', 1542),
#  ('You', 1418),
#  ('but', 1413),
#  ('your', 1409),
#  ('was', 1377),
#  ('are', 1370),
#  ('have', 1335),
#  ('[', 1257),
#  (']', 1255),
#  ('he', 1235),
#  ('girl', 1200),
#  ('know', 1189),
#  ('m', 1170),
#  ('from', 1169)]

# %%
wordcount={}

for word in shakesperewords:
    if word not in wordcount:
        wordcount[word] = 1
    else:
        wordcount[word] += 1

for k,v in wordcount.items():
    print (k, v)
# Out:
# Religious 1
# vnreclaim 1
# clothes 1
# Eternity 1
# agitation 1
# oh 9
# knife 2
# poorely 1
# Natures 9
# Seeing 2
# continued 1
# Compulsatiue 1
# False 2
# Abuse 1
# studied 1
# deseru 4
# redresse 7
# pocket 1
# resounds 1
# Folded 1
# dum 1
# flowt 1
# Beard 4
# fetch 7
# part 37
# Barres 1
# Sacrifice 1
# Doth 5
# drabbing 1
# twaine 3
# threats 2
# Indentures 1
# nor 52
# Kinde 2
# gently 3
# Canker 2
# confident 1
# disperse 1
# Spaniell 1
# vntyr 1
# arbitrate 1
# Carkasse 1
# Battalians 1
# Faults 1
# attendant 2
# muddied 1
# Mornings 1
# Anthonies 1
# palpable 2
# Bond 6
# Puzels 1
# Deuices 1
# disappointed 1
# striue 1
# remain 2
# lookes 11
# Statute 1
# plunged 1
# fearefulnesse 1
# Heart 16
# How 97
# among 2
# Giues 4
# newes 10
# whereon 3
# foe 1
# Chickens 1
# Marcus 5
# Comming 1
# sland 1
# lacks 2
# Came 3
# stricken 1
# harrow 1
# Calue 1
# old 24
# heauiest 1
# waues 2
# England 28
# Stormes 1
# exposure 1
# Will 62
# resemble 1
# women 4
# permanent 1
# ...

# %%
wordcount={}

for word in webwords:
    if word not in wordcount:
        wordcount[word] = 1
    else:
        wordcount[word] += 1

for k,v in wordcount.items():
    print (k, v)
# Out:
# Muthafucka 1
# Krack 2
# nonstop 1
# clothes 26
# aboveground 2
# crap 9
# methods 3
# Lafayette 1
# knife 14
# Alsace 1
# pages 143
# dental 2
# Applets 4
# mpg 2
# Wangsta 1
# del 1
# martial 2
# Autojoin 1
# unarmed 1
# Beetroot 1
# modified 7
# Je 1
# Double 22
# Strung 1
# apricoty 1
# pocket 7
# recommend 3
# boxes 47
# Copied 1
# advantage 4
# Tony 7
# Victoria 2
# Quartet 1
# unreasonably 2
# argyle 3
# Educated 1
# flavoured 1
# GeForce 1
# Recover 1
# thunder 3
# Full 24
# napkins 1
# dynasty 1
# humorous 1
# medical 5
# Amongst 1
# threats 1
# vache 2
# seduce 1
# cupped 1
# pen 3
# treasure 2
# saliva 1
# JFK 5
# "> 4
# closed 69
# Christina 3
# Leaner 1
# brownstone 2
# liquid 1
# flee 1
# inflexible 1
# Slideshow 1
# Reimplement 1
# lines 12
# schooled 1
# contributor 5
# dickbag 1
# fashionista 3
# Kissena 1
# WAKE 1
# disappointed 8
# remain 6
# definition 4
# Pomerol 1
# Beneath 1
# Sunday 9
# How 169
# Labrador 2
# Mercrdes 1
# parameter 10
# Barista 15
# crib 3
# ...

# %%
order1=FreqDist(shakesperewords)
order2=FreqDist(webwords)

# %%
top1=order1.most_common(50)
top2=order2.most_common(50)

# %%
top1
top2
# Out:
# [('.', 17689),
#  (':', 14114),
#  (',', 12320),
#  ("'", 10737),
#  ('I', 7828),
#  ('the', 7318),
#  ('to', 6265),
#  ('a', 5744),
#  ('you', 4504),
#  ('?', 4343),
#  ('in', 4195),
#  ('and', 4082),
#  ('!', 4059),
#  ('#', 3710),
#  ('t', 3519),
#  ('-', 3288),
#  ('s', 3250),
#  ('on', 3228),
#  ('of', 3138),
#  ('is', 2879),
#  ('it', 2605),
#  ('"', 2601),
#  ('not', 2438),
#  ('that', 2279),
#  ('1', 2261),
#  ('with', 1910),
#  ('for', 1854),
#  ('Girl', 1755),
#  ('2', 1709),
#  ('Guy', 1659),
#  ('when', 1626),
#  ('like', 1580),
#  ('...', 1542),
#  ('my', 1347),
#  ('have', 1335),
#  ('me', 1305),
#  ('be', 1303),
#  ('You', 1299),
#  (']', 1245),
#  ('[', 1244),
#  ('this', 1219),
#  ('was', 1201),
#  ('girl', 1200),
#  ('m', 1161),
#  ('but', 1139),
#  ('are', 1098),
#  ('don', 1088),
#  ('guy', 1086),
#  ('know', 1020),
#  ('from', 996)]

# %%
top1
# Out:
# [(',', 7058),
#  ('.', 4417),
#  ('the', 1893),
#  ("'", 1750),
#  (':', 1541),
#  ('I', 1417),
#  ('and', 1391),
#  ('to', 1257),
#  ('of', 1227),
#  ('you', 1005),
#  ('?', 996),
#  ('a', 903),
#  ('my', 793),
#  ('in', 736),
#  ('is', 700),
#  ('not', 690),
#  ('d', 662),
#  ('it', 658),
#  ('And', 645),
#  ('that', 615),
#  ('his', 545),
#  ('me', 525),
#  ('your', 480),
#  ('with', 477),
#  (';', 456),
#  ('this', 452),
#  ('him', 433),
#  ('be', 432),
#  ('haue', 406),
#  ('for', 369),
#  ('he', 365),
#  ('Ham', 337),
#  ('The', 327),
#  ('so', 324),
#  ('will', 322),
#  ('s', 301),
#  ('our', 300),
#  ('as', 297),
#  ('Lord', 293),
#  ('-', 293),
#  ('That', 289),
#  ('but', 274),
#  ('are', 272),
#  ('on', 260),
#  ('shall', 259),
#  ('To', 258),
#  ('thou', 256),
#  ('all', 252),
#  ('do', 245),
#  ('What', 239)]

# %%
top2
# Out:
# [('.', 17689),
#  (':', 14114),
#  (',', 12320),
#  ("'", 10737),
#  ('I', 7828),
#  ('the', 7318),
#  ('to', 6265),
#  ('a', 5744),
#  ('you', 4504),
#  ('?', 4343),
#  ('in', 4195),
#  ('and', 4082),
#  ('!', 4059),
#  ('#', 3710),
#  ('t', 3519),
#  ('-', 3288),
#  ('s', 3250),
#  ('on', 3228),
#  ('of', 3138),
#  ('is', 2879),
#  ('it', 2605),
#  ('"', 2601),
#  ('not', 2438),
#  ('that', 2279),
#  ('1', 2261),
#  ('with', 1910),
#  ('for', 1854),
#  ('Girl', 1755),
#  ('2', 1709),
#  ('Guy', 1659),
#  ('when', 1626),
#  ('like', 1580),
#  ('...', 1542),
#  ('my', 1347),
#  ('have', 1335),
#  ('me', 1305),
#  ('be', 1303),
#  ('You', 1299),
#  (']', 1245),
#  ('[', 1244),
#  ('this', 1219),
#  ('was', 1201),
#  ('girl', 1200),
#  ('m', 1161),
#  ('but', 1139),
#  ('are', 1098),
#  ('don', 1088),
#  ('guy', 1086),
#  ('know', 1020),
#  ('from', 996)]

# %%
import string
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import re
sentence = shakesperewords.lower()
tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(sentence)
filtered_words = [w for w in tokens if not w in stopwords.words('english')]
return " ".join(filtered_words)
# Out:
#   File "<ipython-input-47-8528b08ab27f>", line 6
#     sentence = shakesperewords.lower()
#     ^
# IndentationError: unexpected indent

# %%
import string
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import re
sentence = shakesperewords.lower()
tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(sentence)
filtered_words = [w for w in tokens if not w in stopwords.words('english')]
return " ".join(filtered_words)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-1d833584fbfc> in <module>()
#       3 from nltk.corpus import stopwords
#       4 import re
# ----> 5 sentence = shakesperewords.lower()
#       6 tokenizer = RegexpTokenizer(r'\w+')
#       7 tokens = tokenizer.tokenize(sentence)
#
# AttributeError: 'LazyConcatenation' object has no attribute 'lower'

# %%
import string
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import re
tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(shakesperewords)
filtered_words = [w for w in tokens if not w in stopwords.words('english')]
return " ".join(filtered_words)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-a63d722412b7> in <module>()
#       4 import re
#       5 tokenizer = RegexpTokenizer(r'\w+')
# ----> 6 tokens = tokenizer.tokenize(shakesperewords)
#       7 filtered_words = [w for w in tokens if not w in stopwords.words('english')]
#       8 return " ".join(filtered_words)
#
# C:\Users\rajas\Anaconda3\lib\site-packages\nltk\tokenize\regexp.py in tokenize(self, text)
#     127         # If our regexp matches tokens, use re.findall:
#     128         else:
# --> 129             return self._regexp.findall(text)
#     130
#     131     def span_tokenize(self, text):
#
# TypeError: expected string or bytes-like object

# %%
from nltk.corpus import stopwords
filtered_words = [word for word in word_list if word not in stopwords.words('english')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-a1195060a31c> in <module>()
#       1 from nltk.corpus import stopwords
# ----> 2 filtered_words = [word for word in word_list if word not in stopwords.words('english')]
#
# NameError: name 'word_list' is not defined

# %%
from nltk.corpus import stopwords
filtered_words = [word for word in shakesperewords if word not in stopwords.words('english')]

# %%
filtered_words
# Out:
# ['[',
#  'The',
#  'Tragedie',
#  'Julius',
#  'Caesar',
#  'William',
#  'Shakespeare',
#  '1599',
#  ']',
#  'Actus',
#  'Primus',
#  '.',
#  'Scoena',
#  'Prima',
#  '.',
#  'Enter',
#  'Flauius',
#  ',',
#  'Murellus',
#  ',',
#  'certaine',
#  'Commoners',
#  'ouer',
#  'Stage',
#  '.',
#  'Flauius',
#  '.',
#  'Hence',
#  ':',
#  'home',
#  'idle',
#  'Creatures',
#  ',',
#  'get',
#  'home',
#  ':',
#  'Is',
#  'Holiday',
#  '?',
#  'What',
#  ',',
#  'know',
#  '(',
#  'Being',
#  'Mechanicall',
#  ')',
#  'ought',
#  'walke',
#  'Vpon',
#  'labouring',
#  'day',
#  ',',
#  'without',
#  'signe',
#  'Of',
#  'Profession',
#  '?',
#  'Speake',
#  ',',
#  'Trade',
#  'art',
#  'thou',
#  '?',
#  'Car',
#  '.',
#  'Why',
#  'Sir',
#  ',',
#  'Carpenter',
#  'Mur',
#  '.',
#  'Where',
#  'thy',
#  'Leather',
#  'Apron',
#  ',',
#  'thy',
#  'Rule',
#  '?',
#  'What',
#  'dost',
#  'thou',
#  'thy',
#  'best',
#  'Apparrell',
#  '?',
#  'You',
#  'sir',
#  ',',
#  'Trade',
# ...

# %%
order1=FreqDist(filtered_words)

# %%
top5=order1.most_common(50)

# %%
top5
# Out:
# [(',', 7058),
#  ('.', 4417),
#  ("'", 1750),
#  (':', 1541),
#  ('I', 1417),
#  ('?', 996),
#  ('And', 645),
#  (';', 456),
#  ('haue', 406),
#  ('Ham', 337),
#  ('The', 327),
#  ('Lord', 293),
#  ('-', 293),
#  ('That', 289),
#  ('shall', 259),
#  ('To', 258),
#  ('thou', 256),
#  ('What', 239),
#  ('But', 236),
#  ('King', 231),
#  ('Enter', 225),
#  ('Caesar', 192),
#  ('vs', 183),
#  ('thy', 175),
#  ('thee', 174),
#  ('know', 169),
#  ('good', 165),
#  ('For', 164),
#  ('Brutus', 162),
#  ('Bru', 153),
#  ('come', 151),
#  ('would', 142),
#  ('like', 142),
#  ('selfe', 139),
#  ('Macb', 137),
#  ('If', 132),
#  ('man', 132),
#  ('As', 130),
#  ('vpon', 126),
#  ('well', 126),
#  ('He', 126),
#  ('let', 122),
#  ('O', 122),
#  ('may', 121),
#  ('My', 121),
#  ('It', 120),
#  ('You', 119),
#  ('A', 116),
#  ('must', 116),
#  ('hath', 115)]

# %%
from nltk.corpus import stopwords
filtered = [word for word in webwords if word not in stopwords.words('english')]

# %%
order2=FreqDist(filtered)

# %%
top6=order2.most_common(50)

# %%
top6
# Out:
# [('.', 17689),
#  (':', 14114),
#  (',', 12320),
#  ("'", 10737),
#  ('I', 7828),
#  ('?', 4343),
#  ('!', 4059),
#  ('#', 3710),
#  ('-', 3288),
#  ('"', 2601),
#  ('1', 2261),
#  ('Girl', 1755),
#  ('2', 1709),
#  ('Guy', 1659),
#  ('like', 1580),
#  ('...', 1542),
#  ('You', 1299),
#  (']', 1245),
#  ('[', 1244),
#  ('girl', 1200),
#  ('guy', 1086),
#  ('know', 1020),
#  ('(', 909),
#  ('No', 796),
#  ('get', 785),
#  ('It', 779),
#  ('Yeah', 772),
#  ('page', 723),
#  ('What', 713),
#  (')', 700),
#  ('Oh', 664),
#  ('one', 642),
#  ('Woman', 640),
#  ('window', 630),
#  ('Firefox', 602),
#  ('The', 583),
#  ('cell', 577),
#  ('open', 567),
#  ('So', 556),
#  ('Teen', 550),
#  ('man', 543),
#  ('work', 528),
#  ('Chick', 514),
#  ('Man', 511),
#  ('That', 511),
#  ('new', 506),
#  ('***', 498),
#  ('go', 496),
#  ('bar', 490),
#  ('good', 488)]
